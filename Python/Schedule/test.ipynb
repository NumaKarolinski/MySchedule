# %%
import my_schedule
import datetime

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_2')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_day()
print(a_schedule.day_schedules)
print(a_schedule.last_day_in_calendar)
print(datetime.datetime.now().date())
print((datetime.datetime.now().date() - a_schedule.last_day_in_calendar).days)
# Out:
#              0:00   0:05   0:10   0:15   0:20   0:25   0:30   0:35   0:40  \
# 2020-08-26  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep
# 2020-08-27  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep
#
#              0:45  ...  23:10  23:15  23:20  23:25  23:30  23:35  23:40  \
# 2020-08-26  Sleep  ...  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep
# 2020-08-27  Sleep  ...  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep  Sleep
#
#             23:45  23:50  23:55
# 2020-08-26  Sleep  Sleep  Sleep
# 2020-08-27  Sleep  Sleep  Sleep
#
# [2 rows x 288 columns]
# 2020-08-27
# 2020-08-28
# 1

# %%
import datetime
import pandas as pd
import numpy as np

todays_date = datetime.datetime.now().date()

index = pd.date_range(todays_date - datetime.timedelta(1), periods = 1, freq = 'D')

hours = [str(i) for i in range(24)]
minutes = ['00', '05'] + [str(10 + (5 * i)) for i in range(10)]
columns = [hour + ':' + minute for hour in hours for minute in minutes]

data = np.array([np.array(['Sleep'] * len(columns))])

print(data.shape)

print(data.T.shape)

self._day_schedules = pd.DataFrame(data, index = index, columns = columns)
# Out:
# (1, 48)
# (48, 1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7a3ba79fcfb2> in <module>
#      20 print(data.T.shape)
#      21
# ---> 22 self._day_schedules = pd.DataFrame(data, index = index, columns = columns)
#
# NameError: name 'self' is not defined

# %%
hours = [str(i) for i in range(24)]
minutes = ['00', '05'] + [str(10 + (5 * i)) for i in range(10)]
columns = [hour + ':' + minute for hour in hours for minute in minutes]
print(columns)
# Out:
# ['0:00', '0:05', '0:10', '0:15', '0:20', '0:25', '0:30', '0:35', '0:40', '0:45', '0:50', '0:55', '1:00', '1:05', '1:10', '1:15', '1:20', '1:25', '1:30', '1:35', '1:40', '1:45', '1:50', '1:55', '2:00', '2:05', '2:10', '2:15', '2:20', '2:25', '2:30', '2:35', '2:40', '2:45', '2:50', '2:55', '3:00', '3:05', '3:10', '3:15', '3:20', '3:25', '3:30', '3:35', '3:40', '3:45', '3:50', '3:55', '4:00', '4:05', '4:10', '4:15', '4:20', '4:25', '4:30', '4:35', '4:40', '4:45', '4:50', '4:55', '5:00', '5:05', '5:10', '5:15', '5:20', '5:25', '5:30', '5:35', '5:40', '5:45', '5:50', '5:55', '6:00', '6:05', '6:10', '6:15', '6:20', '6:25', '6:30', '6:35', '6:40', '6:45', '6:50', '6:55', '7:00', '7:05', '7:10', '7:15', '7:20', '7:25', '7:30', '7:35', '7:40', '7:45', '7:50', '7:55', '8:00', '8:05', '8:10', '8:15', '8:20', '8:25', '8:30', '8:35', '8:40', '8:45', '8:50', '8:55', '9:00', '9:05', '9:10', '9:15', '9:20', '9:25', '9:30', '9:35', '9:40', '9:45', '9:50', '9:55', '10:00', '10:05', '10:10', '10:15', '
# ...

# %%
(-1 * datetime.datetime.now().weekday()) + 7
# Out:
# 3

# %%
import my_schedule
import datetime

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_day()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:45  ...              23:10              23:15  \
# 2020-08-28  Nothing Scheduled  ...  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  ...  Nothing Scheduled  Nothing Scheduled
#
#                         23:20              23:25              23:30  \
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_day()
a_schedule.add_new_null_day()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:45  ...              23:10              23:15  \
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_days(3)
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-31  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-31  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_days(5)
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-31  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-09-01  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-09-02  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-31  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-09-01  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-09-02  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_1')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_days_until_today()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-26              Sleep              Sleep              Sleep
# 2020-08-27  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-26              Sleep              Sleep              Sleep
# 2020-08-27  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-26              Sleep              Sleep              Sleep
# 2020-08-27  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_days_until_today()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:45  ...              23:10              23:15  \
# 2020-08-28  Nothing Scheduled  ...  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  ...  Nothing Scheduled  Nothing Scheduled
#
#                         23:20              23:25              23:30  \
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_1')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_rest_of_week()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-26              Sleep              Sleep              Sleep
# 2020-08-27  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-26              Sleep              Sleep              Sleep
# 2020-08-27  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-26              Sleep              Sleep              Sleep
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_rest_of_week()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:45  ...              23:10              23:15  \
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_rest_of_week()
#This error response should be fixed by having a warning instead.
a_schedule.add_new_null_rest_of_week()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:45  ...              23:10              23:15  \
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_1')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_rest_of_work_week()
a_schedule.day_schedules
# Out:
# /home/numakarolinski/MySchedule/Python/Schedule/my_schedule.py:116: UserWarning: It is not currently the work week.
#   warnings.warn(message = "It is not currently the work week.")
#                          0:00               0:05               0:10  \
# 2020-08-26              Sleep              Sleep              Sleep
# 2020-08-27  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-26              Sleep              Sleep              Sleep
# 2020-08-27  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_rest_of_work_week()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:45  ...              23:10              23:15  \
# 2020-08-28  Nothing Scheduled  ...  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  ...  Nothing Scheduled  Nothing Scheduled
#
#                         23:20              23:25              23:30  \
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_1')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_rest_of_weekend()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-26              Sleep              Sleep              Sleep
# 2020-08-27  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-26              Sleep              Sleep              Sleep
# 2020-08-27  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-26              Sleep              Sleep              Sleep
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_rest_of_weekend()
a_schedule.day_schedules
# Out:
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:45  ...              23:10              23:15  \
# ...

# %%
a_schedule = my_schedule.my_schedule(schedule_name = 'test_3')
#a_schedule._day_schedules.to_pickle(path = a_schedule._full_schedule_name)
a_schedule.add_new_null_rest_of_weekend()
a_schedule.add_new_null_rest_of_work_week()
a_schedule.day_schedules
# Out:
# /home/numakarolinski/MySchedule/Python/Schedule/my_schedule.py:116: UserWarning: It is not currently the work week.
#   warnings.warn(message = "It is not currently the work week.")
#                          0:00               0:05               0:10  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:15               0:20               0:25  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-30  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
#
#                          0:30               0:35               0:40  \
# 2020-08-28  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# 2020-08-29  Nothing Scheduled  Nothing Scheduled  Nothing Scheduled
# ...
